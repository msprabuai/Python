# %%
import my_library

# %%
invoice = my_library.Invoice()
invoice.calculate(10000,18)
# Out:
# GST: 1800.0
# Invoice Amount: 11800.0

# %%
emp = my_library.MultipleFunc()
emp.calculate(50000)
emp.deposit(25000,5000)
# Out:
# Bonus: 5000.0
# Total Salary: 55000.0
# Updated Balance: 30000

# %%
salary = my_library.Salary()
salary.calculate(60000)
# Out:
# Bonus: 6000.0
# Total Salary: 66000.0

# %%
ai = my_library.SubfieldsInAI()
ai.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
gender=input("Enter Gender (M/F): ").upper()
age=int(input("Enter Age: "))
my_library.marriage_eligibility(gender,age)
# Out:
# Enter Gender (M/F):  M
# Enter Age:  23
# Eligible for Marriage

# %%
num=int(input("Enter Number: "))
print(my_library.odd_even(num))
# Out:
# Enter Number:  25
# Odd Number
