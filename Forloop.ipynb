# %%
print()

# %%
print("Welcome to Python Training Program")
# Out:
# Welcome to Python Training Program

# %%
lists=[23,24,56,54,65,43]

# %%
lists = [23,24,56,54,65,43]

for temp1 in lists:
    print(temp1)
# Out:
# 23
# 24
# 56
# 54
# 65
# 43
