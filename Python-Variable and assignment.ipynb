# %%
num1=10
num2=30
print (num1+num2)
# Out:
# 40

# %%
FirstName='Praburam'
print (FirstName)
# Out:
# Praburam

# %%
print ("The addition of first two numbers")
num1=10
num2=30
add=num1+num2
print ("The number1:",num1)
print ("The number2:",num2)
print ("The sum of num1 and num2:",add)
# Out:
# The addition of first two numbers
# The number1: 10
# The number2: 30
# The sum of num1 and num2: 40

# %%
print ("The addition of first two numbers")
num1=int(input("Enter the num1"))
num2=int(input("Enter the num2"))
add=num1+num2
print ("The number1:",num1)
print ("The number2:",num2)
print ("The sum of num1 and num2:",add)
# Out:
# The addition of first two numbers
# Enter the num1 20
# Enter the num2 30
# The number1: 20
# The number2: 30
# The sum of num1 and num2: 50
