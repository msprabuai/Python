# %%
#print statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Inputs and print.
Str = str(input("Enter your institute name: "))
print(Str)
# Out:
# Enter your institute name:  HOPE AI
# HOPE AI

# %%
# Buy Inputs and display outputs.
name = str(input("Enter your name: "))
age = str(input("Enter your age: "))
sname = str(input("Enter your school name: "))
degree = str(input("Enter your degree: "))
# Out:
# Enter your name:  Haris
# Enter your age:  11
# Enter your school name:  JRK
# Enter your degree:  B.E

# %%
#Addition

num1=43
num2=44
add=num1+num2
print(add)
# Out:
# 87

# %%
#Subraction

num1=43
num2=44
sub=num1-num2
print(sub)
# Out:
# -1

# %%
#Multiplication

num1=43
num2=44
mul=num1*num2
print(mul)
# Out:
# 1892

# %%
# Division

num1=43
num2=2
div=num1/num2
print(div)
# Out:
# 21.5

# %%
# Floor Division

num1=43
num2=2
div=(num1//num2)
print(div)
# Out:
# 21

# %%
#modulo operator
# 5 can exists 3 times in 17 and remaning is 2 so 2 is the modulo.
print(17 % 5)
# Out:
# 2
