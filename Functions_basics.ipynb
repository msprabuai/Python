# %%
def hello():
    print("Hello, Welcome to Hope AI!")

hello()
# Out:
# Hello, Welcome to Hope AI!

# %%
#Addition function.
def add(num1, num2): #function def
    result = num1 + num2 # adding two variables to the result 
    return result

answer = add(10, 20) #calling function by passing two values.
print(answer)
# Out:
# 30

# %%
#Subraction function

def subtract(a, b):
    return a - b

print(subtract(50, 20))
# Out:
# 30

# %%
def test():
    print("Hello")
    return 1
    print("World") #after return this print wont execute because after return exit the program.

test()
print("World")
# Out:
# Hello
# World

# %%
def add(a, b):
    result = a + b
    print("Inside Function:", result)
    return result

answer = add(10, 20)
print("Outside Function:", answer)
# Out:
# Inside Function: 30
# Outside Function: 30

# %%
def invoice():
    amount = 10000
    print(amount)
invoice()
# Out:
# 10000

# %%
def invoice():
    amount = 10000
    return amount

invoice_amount = invoice()
print(invoice_amount)
# Out:
# 10000

# %%
def test():
    print("Hello")
    return
    print("World")

test()
# Out:
# Hello

# %%
age=int(input("Enter the age"))
def agecategory():
    if age<18: 
        print("Children")
        cate="Children"
    elif age<35: 
        print("Adult")
        cate="Adult"
    elif age<59: 
        print("Citizen")
        cate="Citizen"
    else:
        print("Senior Citizen")
        cate="Senior Citizen"
    return cate
# Out:
# Enter the age 42

# %%
    agecategory()
# Out:
# Citizen
# 'Citizen'

# %%
agecate=    agecategory()
# Out:
# Citizen

# %%
#calculate simple interest 

def interest(principal, rate, years):
    return (principal * rate * years) / 100

print("Total Interest",interest(10000, 8, 2))
# Out:
# Total Interest 1600.0
